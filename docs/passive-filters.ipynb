# %% [markdown]
# ## Just a bunch of passive filters
#
# **Scott Prahl**
#
# **Dec 2025**

# %%
import ltparser

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### First order filters

# %% [markdown]
# #### First-order RC low-pass filter

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive-filter-low-pass.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 4 5; right
# W 1 6; down
# W 4 7; down
# W 8 9; down
# W 10 11; down
# W 9 11; right
# W 9 0; down
# Vi 6 8 ac 1.000000; down
# R1 2 3 1.0; right
# C1 7 10 1.0; down

# %% [markdown]
# #### First-order RC low-pass filter

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive-filter-low-pass-omega.asc")
lt.make_netlist(renumber_nodes=False)
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 3 2; right
# W 5 4; right
# W 4 1; right
# W 3 6; down
# W 4 7; down
# W 9 8; down
# W 11 10; down
# W 8 10; right
# W 8 0; down
# Vi 6 9 ac 1.000000; down
# R1 2 5 1.0; right
# C1 7 11 1.0; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive-filter-low-with-load.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 4 5; right
# W 5 6; right
# W 1 7; down
# W 4 8; down
# W 5 9; down
# W 10 11; down
# W 12 13; down
# W 11 13; right
# W 14 15; down
# W 13 15; right
# W 11 0; down
# R1 2 3 8000.0; right
# R2 9 14 1000.0; down
# C1 8 12 1e-06; down
# V1 7 10 ac 1.000000; down

# %% [markdown]
# #### First-order RC high-pass filter

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive-filter-high-pass.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 1 5; down
# W 6 5; right
# W 4 7; down
# W 7 8; right
# W 8 9; right
# W 5 10; down
# W 10 11; right
# W 7 12; down
# W 13 12; right
# W 8 14; down
# W 6 15; down
# W 16 17; down
# W 18 19; down
# W 17 19; right
# W 17 0; down
# R2 14 18 2000.0; down
# R1 11 13 6000.0; right
# C1 2 3 1e-06; right
# V1 15 16 ac 1.000000; down

# %% [markdown]
# #### RLC band-pass filter

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive-filter-band-pass.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 5 6; right
# W 6 7; down
# W 1 8; down
# W 9 10; down
# W 10 11; right
# W 12 13; down
# W 11 13; right
# W 11 0; down
# V1 8 9 ac 1.000000; down
# R1 2 3 2.0; right
# L1 4 5 0.01; right
# C1 7 12 4e-06; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive-filter-band-block.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 1 5; down
# W 6 5; right
# W 4 7; down
# W 7 8; right
# W 8 9; right
# W 5 10; down
# W 10 11; right
# W 7 12; down
# W 13 12; right
# W 8 14; down
# W 6 15; down
# W 16 17; down
# W 18 19; down
# W 17 19; right
# W 17 0; down
# R1 14 18 1.0; down
# V1 15 16 ac 1.000000; down
# L1 2 3 10.0; right
# C1 11 13 0.01; right
