# %% [markdown]
# ## Just a bunch of voltmeter or ammeter circuits
#
# **Scott Prahl**
#
# **Dec 2025**

# %%
# %config InlineBackend.figure_format='retina'

import ltparser

# %% [markdown]
# ### Ammeter examples

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm_test_1.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm_test_2.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 5 6; right
# W 1 7; down
# W 6 8; down
# W 9 10; down
# W 11 12; down
# W 10 12; right
# W 10 0; down
# V 7 9 5; down
# R2 4 5 5.0; right
# R1 2 3 5.0; right
# AM1 8 11; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm_test_3.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm_test_4.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm_test_5.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm_test_6.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %% [markdown]
# ### Voltmeter examples

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt_test_1.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt_test_2.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt_test_3.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt_test_4.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt_test_5.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt_test_6.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
