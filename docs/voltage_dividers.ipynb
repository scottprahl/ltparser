# %% [markdown]
# ## Just a bunch of voltage dividers
#
# **Scott Prahl**
#
# **Dec 2025**

# %%
import ltparser

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### Voltage Dividers

# %% [markdown]
# #### First voltage divider
#
# They all pretty much look like this
#
# <img src="images/voltage-divider-1.png" width=20%>

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/voltage-divider-1.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.25)
# Out:
# W 1 2; right
# W 2 3; right
# W 2 4; down
# W 1 5; down
# W 6 7; down
# W 7 8; right
# W 7 9; down
# W 10 11; down
# W 12 13; down
# W 11 13; right
# W 11 0; down
# V 5 10 10; down
# R1 4 6 8.0; down
# R2 9 12 2.0; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/voltage-divider-2.asc")
lt.make_netlist(renumber_nodes=False)
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 4 3; right
# W 3 2; right
# W 3 5; down
# W 4 6; down
# W 8 7; down
# W 7 1; right
# W 7 9; down
# W 11 10; down
# W 13 12; down
# W 10 12; right
# W 10 0; down
# V 6 11 10; down
# R1 5 8 4000.0; down
# R2 9 13 6000.0; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/voltage-divider-3.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 2 3; right
# W 2 4; down
# W 1 5; down
# W 6 7; down
# W 7 8; right
# W 7 9; down
# W 10 11; down
# W 12 13; down
# W 11 13; right
# W 11 0; down
# V 5 10 10; down
# R1 4 6 1000000.0; down
# R2 9 12 9000000.0; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/voltage-divider-4.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 2 3; right
# W 2 4; down
# W 1 5; down
# W 6 7; down
# W 7 8; right
# W 7 9; down
# W 10 11; down
# W 12 13; down
# W 11 13; right
# W 11 0; down
# V 5 10 10; down
# R1 4 6 4000.0; down
# R2 9 12 6000.0; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/voltage-divider-5.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 4 5; right
# W 6 7; right
# W 4 8; down
# W 1 9; down
# W 10 11; down
# W 12 13; down
# W 11 13; right
# W 11 0; down
# V 9 10 10; down
# R1 8 12 1000.0; down
# R2 2 3 4000.0; right
# R3 5 6 5000.0; right

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/voltage-divider-6.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 4 5; right
# W 6 7; right
# W 1 8; down
# W 4 9; down
# W 10 11; down
# W 12 13; down
# W 11 13; right
# W 11 0; down
# V 9 12 10; down
# R1 8 10 1000.0; down
# R2 2 3 4000.0; right
# R3 5 6 5000.0; right

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/voltage-divider-7.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 4 5; right
# W 6 7; right
# W 7 8; right
# W 1 9; down
# W 4 10; down
# W 7 11; down
# W 12 13; down
# W 14 15; down
# W 13 15; right
# W 16 17; down
# W 15 17; right
# W 13 0; down
# V 10 14 10; down
# R1 9 12 1000.0; down
# R2 2 3 4000.0; right
# R3 5 6 5000.0; right
# R4 11 16 5000.0; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/resistors+sources-1.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 4 5; right
# W 6 7; right
# W 7 8; right
# W 8 9; right
# W 9 10; right
# W 4 11; down
# W 7 12; down
# W 9 13; down
# W 10 14; down
# W 1 15; down
# W 16 17; down
# W 17 18; right
# W 19 20; down
# W 18 20; right
# W 21 0_3; down
# W 22 0_2; down
# W 18 23; down
# W 23 24; right
# W 25 26; down
# W 24 26; right
# W 23 27; down
# W 28 0_1; down
# V1 15 21 9; down
# R1 2 3 1000.0; right
# R2 11 22 16000.0; down
# R3 5 6 4000.0; right
# R4 12 16 12000.0; down
# R5 13 19 12000.0; down
# R6 14 25 12000.0; down
# R7 27 28 8000.0; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/resistors+sources-2.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 2 3; right
# W 3 4; right
# W 5 6; right
# W 6 7; right
# W 7 8; right
# W 1 9; down
# W 2 10; down
# W 3 11; down
# W 6 12; down
# W 7 13; down
# W 8 14; down
# W 15 16; down
# W 17 18; down
# W 16 18; right
# W 19 20; down
# W 18 20; right
# W 21 22; down
# W 20 22; right
# W 23 24; down
# W 22 24; right
# W 25 26; down
# W 24 26; right
# W 16 0; down
# I1 15 9 6; up
# I2 25 14 2; up
# I3 5 4 3; left
# R1 10 17 20.0; down
# R2 11 19 10.0; down
# R3 12 21 40.0; down
# R4 13 23 40.0; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/lab-circuit.asc")
lt.make_netlist()
print(lt.netlist)
lt.plot_nodes()

cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 1 3; down
# W 4 5; down
# W 5 6; right
# W 5 7; down
# W 6 0_6; down
# W 8 9; right
# W 10 11; right
# W 11 12; right
# W 13 14; down
# W 14 15; right
# W 11 16; down
# W 8 17; down
# W 17 18; right
# W 9 19; down
# W 20 19; right
# W 19 21; right
# W 22 23; right
# W 23 24; right
# W 25 26; right
# W 27 28; right
# W 23 29; down
# W 30 31; down
# W 32 31; right
# W 31 33; right
# W 25 0_4; down
# W 28 0_5; down
# W 34 0_3; down
# E1 20 30 opamp 24 18
# C1 12 0_1 1e-07; down
# C2 33 0_2 1e-07; down
# R 29 34 50.0; down
# BAT1 3 4 9; down
# BAT2 7 13 9; down
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 8
#       5 lt.plot_nodes()
#       7 cct = lt.circuit()
# ----> 8 cct.draw(scale=0.5)
#
# File ~/Documents/Code/git/ltparser/.venv/lib/python3.12/site-packages/lcapy/netlistmixin.py:847, in NetlistMixin.draw(self, filename, **kwargs)
# ...
