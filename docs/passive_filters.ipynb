# %% [markdown]
# ## Just a bunch of passive filters
#
# **Scott Prahl**
#
# **Dec 2025**

# %%
import ltparser

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### First order filters

# %% [markdown]
# #### First_order RC low_pass filter

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive_filter_low_pass.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 4 5; right
# W 1 6; down
# W 4 7; down
# W 8 9; down
# W 10 11; down
# W 9 11; right
# W 9 0; down
# Vi 6 8 ac 1.000000; down
# R1 2 3 1.0; right
# C1 7 10 1.0; down
# P1 5 0; down, v=Vo

# %% [markdown]
# #### First_order RC low_pass filter

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive_filter_low_pass_omega.asc")
lt.make_netlist(renumber_nodes=False)
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 3 2; right
# W 5 4; right
# W 4 1; right
# W 3 6; down
# W 4 7; down
# W 9 8; down
# W 11 10; down
# W 8 10; right
# W 8 0; down
# Vi 6 9 ac 1.000000; down
# R1 2 5 1.0; right
# C1 7 11 1.0; down
# P1 1 0; down, v=Vo

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive_filter_low_with_load.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 4 5; right
# W 5 6; right
# W 1 7; down
# W 4 8; down
# W 5 9; down
# W 10 11; down
# W 12 13; down
# W 11 13; right
# W 14 15; down
# W 13 15; right
# W 11 0; down
# R1 2 3 8000.0; right
# R2 9 14 1000.0; down
# C1 8 12 1e-06; down
# V1 7 10 ac 1.000000; down
# P1 6 0; down, v=Vo

# %% [markdown]
# #### First_order RC high_pass filter

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive_filter_high_pass.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 1 5; down
# W 6 5; right
# W 4 7; down
# W 7 8; right
# W 8 9; right
# W 5 10; down
# W 10 11; right
# W 7 12; down
# W 13 12; right
# W 8 14; down
# W 6 15; down
# W 16 17; down
# W 18 19; down
# W 17 19; right
# W 17 0; down
# R2 14 18 2000.0; down
# R1 11 13 6000.0; right
# C1 2 3 1e-06; right
# V1 15 16 ac 1.000000; down
# P1 9 0; down, v=Vo

# %% [markdown]
# #### RLC band_pass filter

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive_filter_band_pass.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 5 6; right
# W 6 7; right
# W 6 8; down
# W 1 9; down
# W 10 11; down
# W 11 12; right
# W 13 14; down
# W 12 14; right
# W 12 0; down
# V1 9 10 ac 1.000000; down
# R1 2 3 2.0; right
# L1 4 5 0.01; right
# C1 8 13 4e-06; down
# P1 7 0; down, v=Vo

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/passive_filter_band_block.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 1 5; down
# W 6 5; right
# W 4 7; down
# W 7 8; right
# W 8 9; right
# W 5 10; down
# W 10 11; right
# W 7 12; down
# W 13 12; right
# W 8 14; down
# W 6 15; down
# W 16 17; down
# W 18 19; down
# W 17 19; right
# W 17 0; down
# R1 14 18 1.0; down
# V1 15 16 ac 1.000000; down
# L1 2 3 10.0; right
# C1 11 13 0.01; right
# P1 9 0; down, v=Vo

# %% [markdown]
# ### Audio Cross-over
#
# here is a simple audio crossover
#
# <img src="images/audio_crossover.png" width=100%>

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/audio_crossover.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 2 3; right
# W 4 5; right
# W 5 6; right
# W 7 8; right
# W 8 9; down
# W 10 11; right
# W 12 0_3; down
# W 13 14; right
# W 15 16; right
# W 16 17; right
# W 18 19; right
# W 1 20; down
# W 19 20; right
# W 15 21; down
# W 19 22; down
# W 23 24; right
# W 25 0_2; down
# W 26 0_4; down
# W 27 28; down
# W 20 29; down
# W 29 30; right
# W 30 31; right
# W 32 33; right
# W 33 34; right
# W 34 35; right
# W 36 37; right
# W 37 38; right
# W 39 40; right
# W 33 41; down
# W 40 42; down
# W 43 44; right
# W 45 0_1; down
# W 46 0_5; down
# C_lpf 41 45 5.6000000000000005e-08; down
# R_lpf 31 32 1000.0; right
# Vsine 21 25 ac 1.000000; down
# Rsource 17 18 32.0; right
# C_hpf 3 4 4.700000000000001e-09; right
# C_dc_block 35 36 1e-06; right
# R_Bleeder 22 26 100000.0; down
# Rinl 6 7 10000.0; right
# V_input_bias1 9 12 2.5; down
# Rinr 38 39 10000.0; right
# V_input_bias2 42 46 2.5; down
# ---------------------------------------------------------------------------
# ...

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/audio_crossover.asc")
lt.make_netlist()
lt.plot_nodes()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 2 3; right
# W 4 5; right
# W 5 6; right
# W 7 8; right
# W 8 9; down
# W 10 11; right
# W 12 0_3; down
# W 13 14; right
# W 15 16; right
# W 16 17; right
# W 18 19; right
# W 1 20; down
# W 19 20; right
# W 15 21; down
# W 19 22; down
# W 23 24; right
# W 25 0_2; down
# W 26 0_4; down
# W 27 28; down
# W 20 29; down
# W 29 30; right
# W 30 31; right
# W 32 33; right
# W 33 34; right
# W 34 35; right
# W 36 37; right
# W 37 38; right
# W 39 40; right
# W 33 41; down
# W 40 42; down
# W 43 44; right
# W 45 0_1; down
# W 46 0_5; down
# C_lpf 41 45 5.6000000000000005e-08; down
# R_lpf 31 32 1000.0; right
# Vsine 21 25 ac 1.000000; down
# Rsource 17 18 32.0; right
# C_hpf 3 4 4.700000000000001e-09; right
# C_dc_block 35 36 1e-06; right
# R_Bleeder 22 26 100000.0; down
# Rinl 6 7 10000.0; right
# V_input_bias1 9 12 2.5; down
# Rinr 38 39 10000.0; right
# V_input_bias2 42 46 2.5; down
# ---------------------------------------------------------------------------
# ...
