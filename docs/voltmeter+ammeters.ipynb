# %% [markdown]
# ## Just a bunch of voltmeter or ammeter circuits
#
# **Scott Prahl**
#
# **Dec 2025**

# %%
# %config InlineBackend.figure_format='retina'

import ltparser

# %% [markdown]
# ### Ammeter examples

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm-test-1.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm-test-2.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm-test-3.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm-test-4.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm-test-5.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/amm-test-6.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %% [markdown]
# ### Voltmeter examples

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt-test-1.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt-test-2.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt-test-3.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt-test-4.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt-test-5.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/volt-test-6.asc")
lt.make_netlist()
# print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
