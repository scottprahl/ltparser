# %% [markdown]
# ## Resistors and Sources
#
# **Scott Prahl**
#
# **Dec 2025**

# %%
import ltparser

# %config InlineBackend.figure_format='retina'

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/resistors+sources_1.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 3 4; right
# W 4 5; right
# W 6 7; right
# W 7 8; right
# W 8 9; right
# W 9 10; right
# W 4 11; down
# W 7 12; down
# W 9 13; down
# W 10 14; down
# W 1 15; down
# W 16 17; down
# W 17 18; right
# W 19 20; down
# W 18 20; right
# W 21 0_3; down
# W 22 0_2; down
# W 18 23; down
# W 23 24; right
# W 25 26; down
# W 24 26; right
# W 23 27; down
# W 28 0_1; down
# V1 15 21 9; down
# R1 2 3 1000.0; right
# R2 11 22 16000.0; down
# R3 5 6 4000.0; right
# R4 12 16 12000.0; down
# R5 13 19 12000.0; down
# R6 14 25 12000.0; down
# R7 27 28 8000.0; down

# %%
lt = ltparser.LTspice()
lt.read("../tests/examples/resistors+sources_2.asc")
lt.make_netlist()
print(lt.netlist)
cct = lt.circuit()
cct.draw(scale=0.5)
# Out:
# W 1 2; right
# W 2 3; right
# W 3 4; right
# W 5 6; right
# W 6 7; right
# W 7 8; right
# W 1 9; down
# W 2 10; down
# W 3 11; down
# W 6 12; down
# W 7 13; down
# W 8 14; down
# W 15 16; down
# W 17 18; down
# W 16 18; right
# W 19 20; down
# W 18 20; right
# W 21 22; down
# W 20 22; right
# W 23 24; down
# W 22 24; right
# W 25 26; down
# W 24 26; right
# W 16 0; down
# I1 15 9 6; up
# I2 25 14 2; up
# I3 5 4 3; left
# R1 10 17 20.0; down
# R2 11 19 10.0; down
# R3 12 21 40.0; down
# R4 13 23 40.0; down
